# %% [markdown]
# # MMAI 894 - Deep Learning
# ## Dr. Ofer Shai
# ## Team Bloor
# ### Pothole Detection Model
# Benchmark Model - LeNet-5

# %% [markdown]
# ### 1. Import Modules and Libraries

# %%
# Install module for importing Keras Tuner

# !pip install -q -U keras-tuner

# %%
# Import modules
from sklearn.datasets import fetch_openml
import numpy as np
from numpy import expand_dims
from sklearn.model_selection import train_test_split

# For windows laptops add following 2 lines:
import matplotlib
matplotlib.use('agg')

import matplotlib.pyplot as plt

from matplotlib.pyplot import imshow
# %matplotlib inline

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, AveragePooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm
import os
import random as rn
import cv2
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from keras.utils.np_utils import to_categorical
import kerastuner as kt

np.random.seed(123)
tf.random.set_seed(123)

# %% [markdown]
# ### 2. Load Data
#
#
# *   Data is loaded from Dropbox
# *   There are two (2) datasets that will be uploaded as zipped files and then unzipped in this notebook

# %%
# !wget https://www.dropbox.com/s/u6ymk5ylk9axsuw/no_pothole_v2.zip?dl=0
# Out:
# --2021-03-28 22:36:48--  https://www.dropbox.com/s/u6ymk5ylk9axsuw/no_pothole_v2.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/u6ymk5ylk9axsuw/no_pothole_v2.zip [following]
# --2021-03-28 22:36:49--  https://www.dropbox.com/s/raw/u6ymk5ylk9axsuw/no_pothole_v2.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com/cd/0/inline/BLmsR0Lqfb8-L6E14NsBAvu28YbHaHDrCuLtvAD68mK0AI2F4BeLx50ca1G6T5CfUFPQ7UwGy7amDnJF-Wq8yGjF6RcEgo-zDGallSeBaFapZ-xHvlEXawb4fmQFoAWb3KY_MgnmeHFRCvwzL3IvAMZG/file# [following]
# --2021-03-28 22:36:49--  https://uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com/cd/0/inline/BLmsR0Lqfb8-L6E14NsBAvu28YbHaHDrCuLtvAD68mK0AI2F4BeLx50ca1G6T5CfUFPQ7UwGy7amDnJF-Wq8yGjF6RcEgo-zDGallSeBaFapZ-xHvlEXawb4fmQFoAWb3KY_MgnmeHFRCvwzL3IvAMZG/file
# Resolving uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com (uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6032:15::a27d:520f
# Connecting to uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com (uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BLnZ67Nshyw7rZqxCT-14YYsKxfy6I0CVJtvDIvmlGDfb3MTtBVyy6Tp3hkIKv_kZrTmDP9qA7H0qvCoqw_b6TOVRUFigaHMzHgxqkzOUy2tMmtUAlhyNxwJssBmlq2YzPP3smXbYfOGKutUTRAtbdCMEkbA4BTf4AqoyU8Ad6FXSn603G9_xHmroC-WFzlz81pYv1zJGhuRBEiT-UucTH7oLRTn9yYnBAD40PguBBNQC8SZTNlSqubTTPecUpAYcvHLtNaE5P6BEoY8bMMbr0ZubLcWY_XqFBPj23HU2D-rmBTHPuPOo-5lffeK5YVFR8QBmI57TTGU0IuXaelxlBj3zvwHu7gSe1rXDei2hnc5ZcTqtdZVKcWgG6FZpDaYjSY/file [following]
# --2021-03-28 22:36:49--  https://uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com/cd/0/inline2/BLnZ67Nshyw7rZqxCT-14YYsKxfy6I0CVJtvDIvmlGDfb3MTtBVyy6Tp3hkIKv_kZrTmDP9qA7H0qvCoqw_b6TOVRUFigaHMzHgxqkzOUy2tMmtUAlhyNxwJssBmlq2YzPP3smXbYfOGKutUTRAtbdCMEkbA4BTf4AqoyU8Ad6FXSn603G9_xHmroC-WFzlz81pYv1zJGhuRBEiT-UucTH7oLRTn9yYnBAD40PguBBNQC8SZTNlSqubTTPecUpAYcvHLtNaE5P6BEoY8bMMbr0ZubLcWY_XqFBPj23HU2D-rmBTHPuPOo-5lffeK5YVFR8QBmI57TTGU0IuXaelxlBj3zvwHu7gSe1rXDei2hnc5ZcTqtdZVKcWgG6FZpDaYjSY/file
# Reusing existing connection to uc935fc2fa0b15581b895bd464e8.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 93406489 (89M) [application/zip]
# Saving to: ‘no_pothole_v2.zip?dl=0.1’
#
# no_pothole_v2.zip?d 100%[===================>]  89.08M  17.6MB/s    in 5.7s
#
# 2021-03-28 22:36:56 (15.6 MB/s) - ‘no_pothole_v2.zip?dl=0.1’ saved [93406489/93406489]

# %%
# !wget https://www.dropbox.com/s/edhsf4jxdwdbddz/potholes.zip?dl=0
# Out:
# --2021-03-28 22:36:56--  https://www.dropbox.com/s/edhsf4jxdwdbddz/potholes.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.82.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.82.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/edhsf4jxdwdbddz/potholes.zip [following]
# --2021-03-28 22:36:56--  https://www.dropbox.com/s/raw/edhsf4jxdwdbddz/potholes.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com/cd/0/inline/BLkLRU7s1_4y-8g3zxxffv4dLyJkUrjzncDNaKbcBBmtmrva_tCGRlkJJtX30CJjwoHy1thx5bJjg9IeIV8UNpmYFRUG4m4uA0zKS2q7AoJ4iqcTtXSUoGYPzE3TwOttzgJZg5K6GcUBOaCIVj7bJ4Tf/file# [following]
# --2021-03-28 22:36:57--  https://uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com/cd/0/inline/BLkLRU7s1_4y-8g3zxxffv4dLyJkUrjzncDNaKbcBBmtmrva_tCGRlkJJtX30CJjwoHy1thx5bJjg9IeIV8UNpmYFRUG4m4uA0zKS2q7AoJ4iqcTtXSUoGYPzE3TwOttzgJZg5K6GcUBOaCIVj7bJ4Tf/file
# Resolving uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com (uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com)... 162.125.82.15, 2620:100:6032:15::a27d:520f
# Connecting to uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com (uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com)|162.125.82.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BLkenoak6cwfcp-HSk8z3nX-6U17jSKYtQYZjh4LPSG1aCon6w4jka4siXE-lNgmGyQ1rDJRLMF_F2OsOyZJ06Yi6hKoWzk8u4e6zdTNGJGLGhZUG-QgjByXPAAKJpYy6n6BjQmRTSUU-WftcfSappLzflbEMztn-Lg_9XjThJqyqcm2wMNQdwwkwyc58nWMkfhKVhVAXsijPwor8Ym05aLgX4zE_sZR3WHCHElDqQPlPE9cNCgSrEyc9SU8r76XHmq2dtKzGw5PzsUNUMr4aiSgCeHXRBSnixlHTZHIHd8MHiD5pjF8Z2x9FXK93EI-wx50WlHfTFp_JNtT9kgbmU6XgE5RqruA9rR6DGVNBTyfxuLxMnx0oaPSg7rJAgfJh8M/file [following]
# --2021-03-28 22:36:58--  https://uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com/cd/0/inline2/BLkenoak6cwfcp-HSk8z3nX-6U17jSKYtQYZjh4LPSG1aCon6w4jka4siXE-lNgmGyQ1rDJRLMF_F2OsOyZJ06Yi6hKoWzk8u4e6zdTNGJGLGhZUG-QgjByXPAAKJpYy6n6BjQmRTSUU-WftcfSappLzflbEMztn-Lg_9XjThJqyqcm2wMNQdwwkwyc58nWMkfhKVhVAXsijPwor8Ym05aLgX4zE_sZR3WHCHElDqQPlPE9cNCgSrEyc9SU8r76XHmq2dtKzGw5PzsUNUMr4aiSgCeHXRBSnixlHTZHIHd8MHiD5pjF8Z2x9FXK93EI-wx50WlHfTFp_JNtT9kgbmU6XgE5RqruA9rR6DGVNBTyfxuLxMnx0oaPSg7rJAgfJh8M/file
# Reusing existing connection to uc3b0a97da58ee5c4d33ab1ab282.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 355462860 (339M) [application/zip]
# Saving to: ‘potholes.zip?dl=0.1’
#
# potholes.zip?dl=0.1 100%[===================>] 339.00M  19.3MB/s    in 21s
#
# 2021-03-28 22:37:19 (16.3 MB/s) - ‘potholes.zip?dl=0.1’ saved [355462860/355462860]

# %%
# Unzip the No Potholes dataset
# Use '%%capture' to hide output

# %%capture
# !unzip -o '/content/no_pothole_v2.zip?dl=0'

# %%
# Unzip the Potholes dataset
# Use '%%capture' to hide output

# %%capture
# !unzip -o '/content/potholes.zip?dl=0'

# %% [markdown]
# ### 3. Data Preprocessing
#
# The following steps will be taken to preprocess the data:
# 1.   Read in the images from the datasets and resize them
# 2.   Assign each image a label (i.e. No Pothole vs Pothole)
# 3.   Plot sample images to assure the labels have been assigned correctly
# 4.   Encode the labels
# 5. Split the data into training and test sets

# %%
# This function reads in the images one at a time through the 'for' loop and resizes them and assigns a label

def make_train_data(label,DIR):
    for img in tqdm(os.listdir(DIR)):
        try:
            path = os.path.join(DIR,img)
            img = cv2.imread(path,cv2.IMREAD_COLOR)
            img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))

            X.append(np.array(img))
            Z.append(str(label))
        except:
            pass

# %%
# Running the 'make_train_data' function defined above on the two (2) datasets
# X will be a list of images, stored as an array
# Z will be a list of labels 

X=[]
Z=[]
IMG_SIZE=250

no_potholes='../content/no_pothole_v2/'
potholes='../content/potholes/'

make_train_data('NO POTHOLES',no_potholes)
make_train_data('POTHOLES',potholes)
# Out:
# 100%|██████████| 817/817 [00:10<00:00, 76.51it/s]
# 100%|██████████| 718/718 [00:06<00:00, 103.12it/s]

# %%
# Plotting ten (10) randomly selected images, along with their assigned labels as the title

fig,ax=plt.subplots(2,5)
plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0)
fig.set_size_inches(15,15)

for i in range(2):
    for j in range (5):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l][:,:,::-1])
        ax[i,j].set_title(Z[l])
        ax[i,j].set_aspect('equal')

# %%
# Encoding the labels and assigning the encoded labels to 'Y'

from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

le=LabelEncoder()
Y=le.fit_transform(Z)

print(Y)

X=np.array(X)
X=X/255

# Split data into training and test sets
# Assigning 15% of the data to the test sets and remaining to the training sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.15, random_state=42)

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.15, random_state=42)
# Out:
# [0 0 0 ... 1 1 1]

# %%
# Printing shapes of X, X_train, and X_test to assure the split was done correctly

print(X.shape)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (1534, 250, 250, 3)
# (1107, 250, 250, 3)
# (231, 250, 250, 3)
# (196, 250, 250, 3)

# %% [markdown]
# ### 4. Modelling - Training and Building Model
#
#
# *   Building the model architecture and defining hyperparameters to be tuned
# *   Running a search to find the optimal hyperparameter values
# *   Building the model using the optimal hyperparameter values

# %%
# Build Model using LeNet-5 architecture

model = keras.Sequential()

# First convolutional layer
model.add(Conv2D(filters=6, kernel_size=(5, 5), strides=(1, 1), activation='tanh', input_shape=(250,250,3), padding='valid'))
model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

# Second convolutional layer
model.add(Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), activation='tanh'))
model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

model.add(Flatten())

# First Dense Layer
model.add(Dense(units=120, activation='tanh'))

# Second Dense Layer
model.add(Dense(units=84, activation='tanh'))

# Output Layer
model.add(Dense(units=1, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 246, 246, 6)       456
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 123, 123, 6)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 119, 119, 16)      2416
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 59, 59, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 55696)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               6683640
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 6,696,761
# Trainable params: 6,696,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model

model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
# Train model

history = model.fit(x=X_train, y=Y_train, batch_size=128, epochs=20, verbose=1,validation_data=(X_val, Y_val))
# Out:
# Epoch 1/20
# 9/9 [==============================] - 3s 171ms/step - loss: 2.4528 - accuracy: 0.4582 - val_loss: 1.0999 - val_accuracy: 0.4184
# Epoch 2/20
# 9/9 [==============================] - 1s 76ms/step - loss: 0.8738 - accuracy: 0.4894 - val_loss: 0.8395 - val_accuracy: 0.5816
# Epoch 3/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.8211 - accuracy: 0.5276 - val_loss: 0.7183 - val_accuracy: 0.4184
# Epoch 4/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.7187 - accuracy: 0.4699 - val_loss: 0.7273 - val_accuracy: 0.4184
# Epoch 5/20
# 9/9 [==============================] - 1s 74ms/step - loss: 0.7018 - accuracy: 0.4829 - val_loss: 0.6804 - val_accuracy: 0.5816
# Epoch 6/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6965 - accuracy: 0.5278 - val_loss: 0.6799 - val_accuracy: 0.5816
# Epoch 7/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6924 - accuracy: 0.5272 - val_loss: 0.6961 - val_accuracy: 0.4184
# Epoch 8/20
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6938 - accuracy: 0.4973 - val_loss: 0.6883 - val_accuracy: 0.5816
# Epoch 9/20
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6918 - accuracy: 0.5299 - val_loss: 0.6803 - val_accuracy: 0.5816
# Epoch 10/20
# 9/9 [==============================] - 1s 77ms/step - loss: 0.6974 - accuracy: 0.5094 - val_loss: 0.6932 - val_accuracy: 0.4184
# Epoch 11/20
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6929 - accuracy: 0.5044 - val_loss: 0.6842 - val_accuracy: 0.5816
# Epoch 12/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6922 - accuracy: 0.5252 - val_loss: 0.6858 - val_accuracy: 0.5816
# Epoch 13/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6913 - accuracy: 0.5318 - val_loss: 0.6865 - val_accuracy: 0.5816
# Epoch 14/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6925 - accuracy: 0.5219 - val_loss: 0.6886 - val_accuracy: 0.5816
# Epoch 15/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6915 - accuracy: 0.5371 - val_loss: 0.6826 - val_accuracy: 0.5816
# Epoch 16/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6966 - accuracy: 0.4864 - val_loss: 0.6922 - val_accuracy: 0.5816
# Epoch 17/20
# 9/9 [==============================] - 1s 76ms/step - loss: 0.6924 - accuracy: 0.5278 - val_loss: 0.6822 - val_accuracy: 0.5816
# Epoch 18/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6918 - accuracy: 0.5292 - val_loss: 0.6885 - val_accuracy: 0.5816
# Epoch 19/20
# 9/9 [==============================] - 1s 75ms/step - loss: 0.6928 - accuracy: 0.5170 - val_loss: 0.6873 - val_accuracy: 0.5816
# Epoch 20/20
# 9/9 [==============================] - 1s 72ms/step - loss: 0.6920 - accuracy: 0.5262 - val_loss: 0.6828 - val_accuracy: 0.5816

# %% [markdown]
# ### 5. Model Evaluation

# %%
# Evaluate model
# This model has trained on the full 50 epochs

test_loss, test_accuracy = model.evaluate(X_test, Y_test)

print("Test Loss: {:.3f}, Test Accuracy: {:.3f}".format(test_loss, test_accuracy))
# Out:
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6935 - accuracy: 0.5195
# Test Loss: 0.693, Test Accuracy: 0.519

# %%
# Generate Classification Report
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

target_names = ['No Pothole', 'Pothole']

print(classification_report(Y_test, y_pred.round(), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#   No Pothole       0.52      1.00      0.68       120
#      Pothole       0.00      0.00      0.00       111
#
#     accuracy                           0.52       231
#    macro avg       0.26      0.50      0.34       231
# weighted avg       0.27      0.52      0.36       231
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Plot training and validation accuracy and loss over epochs

#  "Accuracy"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Plotting incorrect predictions

# Assigning the predicted and actual outputs to a class (0 or 1)
Y_pred_classes = y_pred.round()
Y_test_classes = Y_test.round()

# Creating a blank list for all incorrect predictions
inc_pred = []
    
# Comparing the predicted and actual outputs and adding the index of the incorrect predictions to the inc_pred list
for x in range(0,len(Y_pred_classes)):
  if Y_pred_classes[x] != Y_test_classes[x]:
    inc_pred.append(x)

# Creating a sample of the first five (5) incorrect predictions
inc_pred_sample = inc_pred[:5]
inc_pred_sample2 = inc_pred[5:10]

# Plotting the sample of five (5) incorrect predictions
n_plots = len(inc_pred_sample2)

f, ax2=plt.subplots(1, 5, figsize=(20,20))
plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0)
f.set_size_inches(15,15)

for i in range(0,n_plots):
    value = X_test[inc_pred_sample2[i]][:,:,::-1]
    ax2[i].imshow(value.reshape(250,250,3))
    ax2[i].set_title("Predicted: {}, Actual: {}".format(int(Y_pred_classes[inc_pred_sample2[i]][0]),Y_test_classes[inc_pred_sample2[i]]), fontsize=8)
    ax2[i].set_aspect('equal')

# %% [markdown]
# # Extra Work - Remove before submission

# %%
# import random image

# test_path = '../content/test_image13.jpg'

# test_img = cv2.imread(test_path,cv2.IMREAD_COLOR)
# test_img = cv2.resize(test_img, (IMG_SIZE,IMG_SIZE))

# fig1,ay=plt.subplots(1,1)
# plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0)
# fig1.set_size_inches(15,15)

# ay.imshow(test_img)

# %%
# test_img_dim = expand_dims(test_img, axis=0)

# test_img_dim.shape

# %%
# predict class of random image

# test_pred = hypermodel.predict(test_img_dim)

# print(test_pred)

# prediction = test_pred.round()

# print(prediction)

# if prediction == 0:
#   print("This image has no potholes")

# else:
#   print("This image has potholes")
